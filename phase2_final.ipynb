# %%
import os, sys
import numpy as np
import pyodbc
import pandas as pd
import csv
cnxn = pyodbc.connect("DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;PORT=1433;DATABASE=testingdatabase;UID=sa;PWD=CaVysyb@W2200am$")
cursor = cnxn.cursor()
query = "SELECT * from dbo.amazon_test_working_copy_1;"
import warnings
import datetime
warnings.filterwarnings("ignore")
df = pd.read_sql(query, cnxn)
test = df
test
# Out:
#      record_id pickup_date  pickup_hour delivery_end_date  delivery_end_hour  \
# 0            1  2020-09-20         12.0        2020-09-21                NaN
# 1            2  2020-09-21          NaN        2020-09-21                NaN
# 2            3  2020-09-21          NaN        2020-09-21                NaN
# 3            4  2020-09-21         12.0        2020-09-22                NaN
# 4            5  2020-09-22          NaN        2020-09-23                NaN
# ..         ...         ...          ...               ...                ...
# 174        175  2020-10-30         20.0        2020-11-03               20.0
# 175        176  2020-10-31          NaN        2020-10-31                NaN
# 176        177  2020-10-31          NaN        2020-10-31                NaN
# 177        178  2020-10-31          NaN        2020-10-31                NaN
# 178        179  2020-10-31          NaN        2020-11-03                NaN
#
# ...

# %%
b_info = {'volume': 0.015, #need more research, just using this number for now
          'weight': 2.2,
          'temp_cost_16': 1.2,
          'temp_cost_53': 1.4
}
c_info = {
    'volume': 0.084, #need more research, just using this number for now
          'weight': 1.79,
          'temp_cost_16': 1.3,
          'temp_cost_53': 1.5
}
f_info = {
    'volume': 0.17, #need more research, just using this number for now
          'weight': 1,
          'temp_cost_16': 1.4,
          'temp_cost_53': 1.6
}
d_info = {
    'volume': 0.11, #need more research, just using this number for now
          'weight': 4,
          'temp_cost_16': 1.5,
          'temp_cost_53': 1.7
}
p1_output_by_temp = {}
p2_output_by_temp = {}

# %%
b_output1['truck_id'].max()
# Out:
# 29

# %%
# run this after the 2 solvers are run for every temperature to join all the outputs in to one
final_p1_output = []
final_p2_output = []
b_output1 = p1_output_by_temp['Banana'].copy()
c_output1 = p1_output_by_temp['Chill'].copy()
f_output1 = p1_output_by_temp['Frozen'].copy()
d_output1 = p1_output_by_temp['Deep Freeze'].copy()

b_output2 = p2_output_by_temp['Banana'].copy()
c_output2 = p2_output_by_temp['Chill'].copy()
f_output2 = p2_output_by_temp['Frozen'].copy()
d_output2 = p2_output_by_temp['Deep Freeze'].copy()

# combine temperature outputs
final_p1_output = b_output1.copy()
# make truck_ids unique across temperatures
c_output1['truck_id'] += final_p1_output['truck_id'].max() + 1
final_p1_output = pd.concat([final_p1_output, c_output1])

f_output1['truck_id'] += final_p1_output['truck_id'].max() + 1
final_p1_output = pd.concat([final_p1_output, f_output1])

d_output1['truck_id'] += final_p1_output['truck_id'].max() + 1
final_p1_output = pd.concat([final_p1_output, d_output1])


# combine temperature outputs
final_p2_output = b_output2.copy()
# make truck_ids unique across temperatures
c_output2['truck_id'] += final_p2_output['truck_id'].max() + 1
final_p2_output = pd.concat([final_p2_output, c_output2])

f_output2['truck_id'] += final_p2_output['truck_id'].max() + 1
final_p2_output = pd.concat([final_p2_output, f_output2])

d_output2['truck_id'] += final_p2_output['truck_id'].max() + 1
final_p2_output = pd.concat([final_p2_output, d_output2])

# make run ids unique across temperatures
final_p1_output['run_id'] = range(len(final_p1_output))
final_p2_output['run_id'] = range(len(final_p2_output))

# save to files
final_p1_output.to_csv('final_p1_output.csv', index=False)
final_p2_output.to_csv('final_p2_output.csv', index=False)

# %%
# Run the first two cells, change the two values below, then go Cell > Run all below

# change this temperature to which output temperature we need
temperature_filter = 'Deep Freeze'
# change this to which week we want
week_filter = 0

# caution: if a week/temperature has 0 orders, one of the cells will return an error and we should exclude that week and temperature

nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
import openrouteservice
import pgeocode
import ortools

# values
volume_16 = 800
weight_16 = 4300
rent_16 = 6.6
labor_16 = 38
mpg_16 = 12

volume_53 = 3849
weight_53 = 44000
rent_53 = 8
# total labor cost paid per hour for one truck, so if we have 2 drivers, we multiply by labor by 2 
labor_53 = 48 *2
mpg_53 = 6.5

truck_speed = 60
gas_price = 2.350

# costs based on temperature
if (temperature_filter == 'Banana'):
    temp_info = b_info
elif (temperature_filter == 'Chill'):
    temp_info = c_info
elif (temperature_filter == 'Frozen'):
    temp_info = f_info
elif (temperature_filter == 'Deep Freeze'):
    temp_info = d_info

# formatting zip codes
test['shipper_zip'] = test['shipper_zip'].apply(lambda x: x[:5])
test['shipper_zip'] = test['shipper_zip'].apply(lambda x: x.zfill(5))

# deciding unit capacity of truck based on weight/volume
unit_capacity_16 = int(min(volume_16 / temp_info["volume"], weight_16 / temp_info["weight"]))
unit_capacity_53 = int(min(volume_53 / temp_info["volume"], weight_53 / temp_info["weight"]))

# filter temperature
sortTable = test.loc[test['temperature'] == temperature_filter + '\r']
# sortTable = test.loc[test['temperature'] == temperature_filter]

sortTable['pickup_date_formatted']= pd.to_datetime(sortTable['pickup_date'])
sortTable = sortTable.sort_values(by="pickup_date_formatted")

weeks = [g for n, 
         g in sortTable.set_index('pickup_date_formatted').groupby(
             pd.Grouper(level='pickup_date_formatted', freq='W'))]


bananas = weeks[week_filter]

split_size = unit_capacity_16  # split one node into units of this size at most
limit = unit_capacity_16 # threshold of when to split orders
bananas = bananas.reset_index(drop=True)

# split demands that are too large
for i in range(len(bananas['unit_count'])):
  units = bananas['unit_count'][i]
  if (units > limit):
    bananas['unit_count'][i] = units % split_size
    units -= bananas['unit_count'][i]
    new_nodes = int(units / split_size)
    new_node = bananas.iloc[i]
    new_node['unit_count'] = split_size
    # print("order id",bananas['record_id'][i], "was split into", new_nodes + 1, "nodes")
    bananas['unit_count']
    # add new nodes 
    for j in range(new_nodes):
      bananas = bananas.append(new_node, ignore_index=True)

# convert zip codes to coordinates, and add hub coordinates to the front of the list
bananasZips = (bananas[['shipper_zip', 'record_id','unit_count']])
hubZip = pd.DataFrame([{'shipper_zip' : '98032', 'record_id': 0 , 'unit_count' : 0}])
bananasZips = hubZip.append(bananasZips).reset_index(drop=True)
nomi = pgeocode.Nominatim('us')
query = nomi.query_postal_code(bananasZips['shipper_zip'].to_numpy())
coords = []
for i in range (len(query)):
  coords.insert(i, [query['longitude'][i], query['latitude'][i]])
len(coords)
# Out:
# 100

# %%
#  create time matrix using openrouteservice api
import requests
def send_request(locs, divider):
  body = {"locations":locs,"destinations": list(range(divider, len(locs))),"metrics":["duration"],"sources": list(range(0,divider))}
  headers = {
      'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
      'Authorization': '5b3ce3597851110001cf624877b6decbd73c49d4844e69cfb6e884d9',
      'Content-Type': 'application/json; charset=utf-8'
  }
  call = requests.post('https://api.openrouteservice.org/v2/matrix/driving-hgv', json=body, headers=headers)
  matrix = call.json()['durations']
  return matrix


# build and combine matrices
main_matrix = [[0]*len(coords) for i in range(len(coords))]
rem = len(coords) % 50
# 
num_blocks = (int)((len(coords) - rem) / 50)
if (num_blocks == 0):
  main_matrix = send_request(coords + coords, len(coords))
else:

  for r in range(num_blocks):
    for c in range(num_blocks):
      dest = coords[c * 50 : c * 50 + 50]
      orig = coords[r * 50 : r * 50 + 50]
      dest = coords[c * 50 : c * 50 + 50]

      small_matrix = send_request(orig + dest, len(orig))
      # join matrices to main matrix
      for i in range (len(small_matrix)):
        for j in range (len(small_matrix)):
          main_matrix[r*50 + i][c*50 + j] = small_matrix[i][j]
      # edge cases
    if (rem > 0): 
      orig = coords[r*50 : r*50 +50]
      dest = coords[50*num_blocks : len(coords)]
      small_matrix = send_request(orig + dest, len(orig))
      # join matrices to main matrix
      for i in range (len(small_matrix)):
        for j in range (len(small_matrix[0])):
          main_matrix[r*50 + i][num_blocks*50 + j] = small_matrix[i][j]

  # bottom edge cases
  if (rem > 0):
    for j50 in range(num_blocks):
        orig = coords[num_blocks*50 : len(coords)]
        dest = coords[j50*50 : j50*50 + 50]
        small_matrix = send_request(orig + dest, len(orig))
        # join matrices to main matrix
        for i in range (len(small_matrix)):
          for j in range (len(small_matrix[0])):
            main_matrix[num_blocks*50 + i][j50*50 + j] = small_matrix[i][j]
        # edge 
        orig = coords[num_blocks*50 : len(coords)]
        dest = coords[50*num_blocks : len(coords)]
        small_matrix = send_request(orig + dest, len(orig))
        # join matrices to main matrix
        for i in range (len(small_matrix)):
          for j in range (len(small_matrix[0])):
            main_matrix[num_blocks*50 + i][num_blocks*50 + j] = small_matrix[i][j]
        # print(main_matrix)

banana_time_matrix = np.array(main_matrix)/60
print(len(banana_time_matrix),"x",len(banana_time_matrix[0]),"time matrix constructed, value = " + str(banana_time_matrix[0][1]))
# Out:
# 100 x 100 time matrix constructed, value = 39.403999999999996

# %%
# convert to time windows: if hour is specified, +-1 hour window, otherwise, 24 hour time window
import math
from datetime import datetime
import datetime
from datetime import timedelta

# Jennifer is making the table that is 

# first sort the table by date (choose the lowest date)

sortTable = bananas

sortTable['pickup_date_formatted']= pd.to_datetime(sortTable['pickup_date'])
sortTable = sortTable.sort_values(by="pickup_date_formatted")

# list of tables weekly
weeks = [g for n, 
         g in sortTable.set_index('pickup_date_formatted').groupby(
             pd.Grouper(level='pickup_date_formatted', freq='Y'))]
for n in weeks :
# # need at least 4 days before first pickup order of the weekto allow for planning and transportation time
  minXdays = 4
  firstDay= n.iloc.obj.index[0]
  minX = datetime.timedelta(days = minXdays)
  depotTime = firstDay - minX
  print("The start time is at ", depotTime)
  tempTimeMatrixList1 = []
  tempTimeMatrixList2 = []

  for index, row in n.iterrows():
    pickupHourTemp = row['pickup_hour']
    hour_temp = int(0)
    minutes_temp = int(0)
    dMinDepotTime = index 
    difference1 = index
    if pickupHourTemp >= 0 :
      hour_temp = int(pickupHourTemp + 1)
      minutes_temp =int(math.ceil(pickupHourTemp % 1 * 60))
      timeMatrixTime = dMinDepotTime.replace(hour= hour_temp
                              ,minute = minutes_temp)
      difference1 = timeMatrixTime - datetime.timedelta(hours = 2)  - depotTime
    else :
      timeMatrixTime = index + datetime.timedelta(days = 1)
      difference1 = index - depotTime
    difference2 = timeMatrixTime - depotTime
    # difference 2 if NaN then add 24 hours
    tempTimeMatrixList1.append((int(abs(difference1).total_seconds()/60), int(abs(difference2).total_seconds()/60)))
    tempTimeMatrixList2.append(int(abs(difference2).total_seconds()/60))

  n['timeWindows1']= tempTimeMatrixList1
  n['timeMatrix2']= tempTimeMatrixList2

time_windows = pd.Series([(0,0)])
# time windows at hub should be (0,0)
time_windows = (time_windows.append(weeks[0]['timeWindows1']).reset_index(drop=True))
# Out:
# The start time is at  2020-09-17 00:00:00

# %%
time_windows
# Out:
# 0             (0, 0)
# 1       (5760, 7200)
# 2       (6420, 6540)
# 3       (5760, 7200)
# 4       (5760, 7200)
#            ...
# 95    (11520, 12960)
# 96    (11520, 12960)
# 97    (11520, 12960)
# 98    (11520, 12960)
# 99    (11520, 12960)
# Length: 100, dtype: object

# %%
# shippers to hub solver
from functools import partial

from ortools.constraint_solver import pywrapcp
from ortools.constraint_solver import routing_enums_pb2

###########################
# Problem Data Definition #
###########################
def create_data_model():
    """Stores the data for the problem"""

    data = {}
    data['time_matrix'] = banana_time_matrix
    data['time_windows'] = time_windows
    data['demands'] = bananasZips['unit_count']
    data['time_per_demand_unit'] = 0 # 0 minutes/unit
    data['temperature'] = temperature_filter
#     TODO: change number of trucks
    data['num_16trucks'] = 10
    data['num_53trucks'] = 20
    data['num_vehicles'] = data['num_16trucks'] + data['num_53trucks']
    data['vehicle_capacities'] = [unit_capacity_16]*data['num_16trucks'] + [unit_capacity_53]*data['num_53trucks']
    data['depot'] = 0
    data['output'] = []
    return data


#######################
# Problem Constraints #
#######################

def create_demand_evaluator(data):
    """Creates callback to get demands at each location."""
    _demands = data['demands']

    def demand_evaluator(manager, node):
        """Returns the demand of the current node"""
        return _demands[manager.IndexToNode(node)]

    return demand_evaluator


def create_time_evaluator(data):
    def travel_time(data, from_node, to_node):
        """Gets the travel times between two locations."""
        if from_node == to_node:
            travel_time = 0
        else:
            travel_time = data['time_matrix'][from_node][to_node]
        return travel_time

    _total_time = data['time_matrix']
    def time_evaluator(manager, from_node, to_node):
        """Returns the total time between the two nodes"""
        return _total_time[manager.IndexToNode(from_node)][manager.IndexToNode(
            to_node)]
    return time_evaluator

# cost evaluator per vehicle
def create_cost_evaluator(data,vehindex):
    """Created call back to get total cost between locations """
    def travel_cost(data, from_node, to_node):
        if from_node == to_node:
            return 0
        else:
            hrs = (float)(data['time_matrix'][from_node][to_node] / 60)
            
            if (data['vehicle_capacities'][vehindex] == unit_capacity_16):
                rent1 = rent_16
                labor1 = labor_16
                mpg1 = mpg_16
                temp_cost1 = temp_info['temp_cost_16']
            elif (data['vehicle_capacities'][vehindex] == unit_capacity_53):
                rent1 = rent_53
                labor1 = labor_53
                mpg1 = mpg_53
                temp_cost1 = temp_info['temp_cost_53']
            cost = (rent1 + labor1 + temp_cost1) * hrs + gas_price * hrs * truck_speed/mpg1
            return cost
        
    _total_cost = [[0]*len(data['demands']) for i in range(len(data['demands']))]
    for from_node in range(len(data['demands'])):
        _total_cost[from_node] = {}
        for to_node in range(len(data['demands'])):
            if from_node == to_node:
                _total_cost[from_node][to_node] = 0
            else:
                _total_cost[from_node][to_node] = (travel_cost(data, from_node, to_node))
    def cost_evaluator(manager, from_node, to_node):
        return _total_cost[manager.IndexToNode(from_node)][manager.IndexToNode(
            to_node)]
    return cost_evaluator

# unit capacity constraints
def add_capacity_constraints(routing, data, demand_evaluator_index):
    """Adds capacity constraint"""
    capacity = 'Capacity'
    routing.AddDimensionWithVehicleCapacity(
        demand_evaluator_index,
        0,  # null capacity slack
        data['vehicle_capacities'],
        True,  # start cumul to zero
        capacity)

def add_time_window_constraints(routing, manager, data, time_evaluator_index):
    """Add Global Span constraint"""
    time = 'Time'
    horizon = 12000000
    routing.AddDimension(
        time_evaluator_index,
        horizon,  # allow waiting time
        horizon,  # maximum time per vehicle
        False,  # don't force start cumul to zero since we are giving TW to start nodes
        time)
    time_dimension = routing.GetDimensionOrDie(time)
    # Add time window constraints for each location except depot
    # and 'copy' the slack var in the solution object (aka Assignment) to print it
    for location_idx, time_window in enumerate(data['time_windows']):
        if location_idx == 0:
            continue
        index = manager.NodeToIndex(location_idx)
        time_dimension.CumulVar(index).SetRange(time_window[0], time_window[1])
        routing.AddToAssignment(time_dimension.SlackVar(index))
    # Add time window constraints for each vehicle start node
    # and 'copy' the slack var in the solution object (aka Assignment) to print it
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        time_dimension.CumulVar(index).SetRange(data['time_windows'][0][0],
                                                data['time_windows'][0][1])
        routing.AddToAssignment(time_dimension.SlackVar(index))
        # Warning: Slack var is not defined for vehicle's end node
        #routing.AddToAssignment(time_dimension.SlackVar(self.routing.End(vehicle_id)))


###########
# Printer #
###########

# change the arrive earliest to depotTime + the specified time in minutes.
def print_solution(data, manager, routing, assignment):  # pylint:disable=too-many-locals
    """Prints assignment on console"""
    print('Objective: {}'.format(assignment.ObjectiveValue()))
    total_distance = 0
    total_load = 0
    total_time = 0
    capacity_dimension = routing.GetDimensionOrDie('Capacity')
    time_dimension = routing.GetDimensionOrDie('Time')
    
#     saves the routing data
    run_id = []
    record_id = []
    pickup_zip = []
    arrive_earliest = []
    arrive_latest = []
    destination_zip = []
    depart_earliest = []
    depart_latest = []
    arrival_if_leave_now = []
    truck_id = []
    truck_type = []
    unit_count = []
    temperature = []
    cost = []
    c = create_time_evaluator(data)
#         prints the output into a dataframe
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        distance = 0
        while not routing.IsEnd(index):
            load_var = capacity_dimension.CumulVar(index)
            time_var = time_dimension.CumulVar(index)
            slack_var = time_dimension.SlackVar(index)

            run_id.append(len(run_id) + 1)
            record_id.append(bananasZips['record_id'][manager.IndexToNode(index)])
            pickup_zip.append(bananasZips['shipper_zip'][manager.IndexToNode(index)])
            arrive_earliest.append(depotTime + timedelta(minutes = assignment.Min(time_var)))
            arrive_latest.append(depotTime + timedelta(minutes = assignment.Max(time_var)))
            destination_zip.append(bananasZips['shipper_zip'][manager.IndexToNode(assignment.Value(routing.NextVar(index)))])
            depart_earliest.append(depotTime + timedelta(minutes = assignment.Min(time_var) + assignment.Min(slack_var)))
            depart_latest.append(depotTime + timedelta(minutes = assignment.Min(time_var) + assignment.Max(slack_var)))
            arrival_if_leave_now.append(depart_earliest[len(depart_earliest) - 1] + timedelta(minutes = data['time_matrix'][manager.IndexToNode(index)][manager.IndexToNode(assignment.Value(routing.NextVar(index)))]))
            truck_id.append(vehicle_id)
            if (vehicle_id + 1  <= data['num_16trucks']):
                truck_type.append("16'")
            else:
                truck_type.append("53'")
            unit_count.append(bananasZips['unit_count'][manager.IndexToNode(index)])
            temperature.append(temperature_filter)
            cost.append(routing.GetArcCostForVehicle(index, assignment.Value(routing.NextVar(index)), vehicle_id))
            plan_output +='{0} Load({1}) Time({2},{3}) Slack({4},{5}) Cost({6})-> {7}\n'.format(
            manager.IndexToNode(index),
            assignment.Value(load_var),
            assignment.Min(time_var),
            assignment.Max(time_var),
            assignment.Min(slack_var), assignment.Max(slack_var),
            routing.GetArcCostForVehicle(index, assignment.Value(routing.NextVar(index)),
                                                 vehicle_id),
            manager.IndexToNode(assignment.Value(routing.NextVar(index))))
            previous_index = index
            index = assignment.Value(routing.NextVar(index))
            distance += routing.GetArcCostForVehicle(previous_index, index,
                                                     vehicle_id)
        load_var = capacity_dimension.CumulVar(index)
        time_var = time_dimension.CumulVar(index)
        slack_var = time_dimension.SlackVar(index)
        plan_output += '{0} Load({1}) Time({2},{3})\n'.format(
            manager.IndexToNode(index),
            assignment.Value(load_var),
            assignment.Min(time_var), assignment.Max(time_var))
        plan_output += 'Cost of the route: {0}m\n'.format(distance)
        plan_output += 'Load of the route: {}\n'.format(
            assignment.Value(load_var))
        plan_output += 'Time of the route: {}\n'.format(
            assignment.Value(time_var))
        print(plan_output)
        total_distance += distance
        total_load += assignment.Value(load_var)
        total_time += assignment.Value(time_var)
    print('Total Cost of all routes: {0}m'.format(total_distance))
    print('Total Load of all routes: {}'.format(total_load))
    print('Total Time of all routes: {0}min'.format(total_time))
    d = {'run_id':run_id, 'record_id': record_id, 'arrive_earliest' : pd.to_datetime(arrive_earliest), 
         'arrive_latest' : pd.to_datetime(arrive_latest), 'pickup_zip' : pickup_zip, 'depart_earliest' : pd.to_datetime(depart_earliest),
         'depart_latest' : pd.to_datetime(depart_latest), 'arrival_if_leave_now': arrival_if_leave_now,  'destination_zip' : destination_zip, 'truck_id' : truck_id, 'truck_type' : truck_type, 'unit_count' : unit_count, 'temperature' : temperature,
         'cost' : cost}
    output = pd.DataFrame(data=d)
    return output

########
# Main #
########
"""Entry point of the program"""
# Instantiate the data problem.
data = create_data_model()

# Create the routing index manager
manager = pywrapcp.RoutingIndexManager(len(data['demands']),
                                       data['num_vehicles'], data['depot'])

# Create Routing Model
routing = pywrapcp.RoutingModel(manager)

# Define weight of each edge of the graph
for i in range(data['num_vehicles']):
    cost_evaluator_index = routing.RegisterTransitCallback(
        partial(create_cost_evaluator(data, i), manager))
    routing.SetArcCostEvaluatorOfVehicle(cost_evaluator_index, i)

# Add Capacity constraint
demand_evaluator_index = routing.RegisterUnaryTransitCallback(
    partial(create_demand_evaluator(data), manager))
add_capacity_constraints(routing, data, demand_evaluator_index)

# Add Time Window constraint
time_evaluator_index = routing.RegisterTransitCallback(
    partial(create_time_evaluator(data), manager))
add_time_window_constraints(routing, manager, data, time_evaluator_index)

# Setting first solution heuristic (cheapest addition).
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)  # pylint: disable=no-member
# Solve the problem.
assignment = routing.SolveWithParameters(search_parameters)
output = print_solution(data, manager, routing, assignment)
# Out:
# Objective: 46918
# Route for vehicle 0:
# 0 Load(0) Time(0,0) Slack(3624,5064) Cost(3448)-> 7
# 7 Load(0) Time(7200,8640) Slack(0,11989208) Cost(3464)-> 0
# 0 Load(10) Time(10792,12000000)
# Cost of the route: 6912m
# Load of the route: 10
# Time of the route: 10792
#
# Route for vehicle 1:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 2:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 3:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 4:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 5:
# ...

# %%
output
# Out:
#      run_id  record_id arrive_earliest arrive_latest pickup_zip  \
# 0         1          0      2020-09-17    2020-09-17      98032
# 1         2         15      2020-09-22    2020-09-23      18015
# 2         3          0      2020-09-17    2020-09-17      98032
# 3         4          0      2020-09-17    2020-09-17      98032
# 4         5          0      2020-09-17    2020-09-17      98032
# ..      ...        ...             ...           ...        ...
# 124     125         10      2020-09-25    2020-09-25      56303
# 125     126         25      2020-09-25    2020-09-26      56303
# 126     127         25      2020-09-25    2020-09-26      56303
# 127     128         25      2020-09-25    2020-09-26      56303
# 128     129          0      2020-09-17    2020-09-17      98032
#
#         depart_earliest       depart_latest    arrival_if_leave_now  \
# 0   2020-09-19 12:24:00 2020-09-20 12:24:00 2020-09-22 00:00:19.030
# ...

# %%
# combine similar trips
i = 0
joined = output.copy().sort_values(by="cost", ascending = False)
joined = joined.reset_index(drop=True)
while (i < len(joined)):
    if (i < len(joined)): 
        row = i
        same_id = joined['record_id'] == joined['record_id'][row]
        same_pickup = joined['pickup_zip'] == joined['pickup_zip'][row]
        same_dest = joined['destination_zip'] == joined['pickup_zip']
        same_truck = joined['truck_id'] == joined['truck_id'][row]
        diff_run = joined['run_id'] != joined['run_id'][row]
        dup = joined.loc[same_id & same_pickup & same_dest & same_truck & diff_run]
        if (len(dup) > 1):
#             delete rows
            joined = joined.loc[~(same_id & same_pickup & same_dest & same_truck & diff_run)]  
            joined['unit_count'][row] += dup['unit_count'].sum() 
            i -=1
            joined = joined.reset_index(drop = True) 
    i+=1
joined['run_id'] = range(len(joined))
print(output['unit_count'].sum() - joined['unit_count'].sum())
print(output['cost'].sum() - joined['cost'].sum())
joined
# Out:
# 0
# 0
#     run_id  record_id     arrive_earliest       arrive_latest pickup_zip  \
# 0        0          0 2020-09-17 00:00:00 2020-09-17 00:00:00      98032
# 1        1         25 2020-09-25 00:00:00 2020-09-26 00:00:00      56303
# 2        2          9 2020-09-23 13:00:00 2020-09-24 00:00:00      56303
# 3        3         25 2020-09-25 00:00:00 2020-09-26 00:00:00      56303
# 4        4          0 2020-09-17 00:00:00 2020-09-17 00:00:00      98032
# 5        5         10 2020-09-24 16:00:00 2020-09-24 16:14:00      56303
# 6        6         13 2020-09-22 00:00:00 2020-09-23 00:00:00      98053
# 7        7          3 2020-09-22 00:00:00 2020-09-22 00:00:00      98005
# 8        8         15 2020-09-22 00:00:00 2020-09-23 00:00:00      18015
# 9        9          0 2020-09-17 00:00:00 2020-09-17 00:00:00      98032
# 10      10         19 2020-09-22 00:00:00 2020-09-23 00:00:00      64141
# 11      11          0 2020-09-17 00:00:00 2020-09-17 00:00:00      98032
# ...

# %%
# joined[(joined['pickup_zip'] == joined['destination_zip']) & joined['record_id'] != 0]

# %%
# determines which receiving sites each receiving site should go to
receiving_sites = ['98466', '98052', '98004', '98116', '98122']
units_distribution = [0, 0, 0, 0, 0]

# use output instead of joined because output has split orders and we won't need to do any more splitting
output[output['destination_zip'] == '98032'][output['record_id'] != 0]
hub_arrivals = output.copy()
hub_arrivals = hub_arrivals.drop(hub_arrivals[hub_arrivals['record_id'] == 0].index).reset_index(drop=True)
sorted = output[output['destination_zip'] == '98032'][output['record_id'] != 0].sort_values('arrival_if_leave_now').reset_index(drop=True)
for i in range(len(sorted)):
    truck = sorted['truck_id'][i]
    hub_arrivals.loc[(hub_arrivals.truck_id == truck),'arrive_earliest']= sorted['arrival_if_leave_now'][i]
# drop record id 0 because we want to know each items availability, no need for 0
# drop column arrive latest
hub_arrivals['pickup_zip'] = ['98032'] * len(hub_arrivals)
# sort hub arrivals by things that arrive at hub first
hub_arrivals = hub_arrivals.sort_values('arrive_earliest').reset_index(drop=True)

# threshold to distribute units
units_threshold = output['unit_count'].sum()/5 - 3000
rs_index = 0
i = 0
while i < (len(hub_arrivals)):
    if (units_distribution[rs_index] >= units_threshold):
        rs_index += 1
        if (rs_index == len(units_distribution)) :
            rs_index = 0
    units_distribution[rs_index] += hub_arrivals['unit_count'][i]
    hub_arrivals['destination_zip'][i] = receiving_sites[rs_index]
    i += 1
hub_arrivals
# Out:
#     run_id  record_id         arrive_earliest arrive_latest pickup_zip  \
# 0       74          5 2020-09-22 03:06:04.820    2020-09-23      98032
# 1       95          5 2020-09-22 03:06:04.820    2020-09-23      98032
# 2       94          5 2020-09-22 03:06:04.820    2020-09-23      98032
# 3       93          5 2020-09-22 03:06:04.820    2020-09-23      98032
# 4       92          5 2020-09-22 03:06:04.820    2020-09-23      98032
# ..     ...        ...                     ...           ...        ...
# 94      60         25 2020-09-26 08:08:18.130    2020-09-26      98032
# 95      61         25 2020-09-26 08:08:18.130    2020-09-26      98032
# 96      62         25 2020-09-26 08:08:18.130    2020-09-26      98032
# 97     127         25 2020-09-26 08:08:18.130    2020-09-26      98032
# 98     128         25 2020-09-26 08:08:18.130    2020-09-26      98032
#
#    depart_earliest       depart_latest    arrival_if_leave_now  \
# ...

# %%
units_distribution
# Out:
# [20425, 20425, 20105, 18586, 19749]

# %%
# receiving sites zips converted to coordinates
rs_zips = (hub_arrivals[['destination_zip', 'record_id','unit_count']])
rs_zips['destination_zip'] = rs_zips['destination_zip'].astype(str)

hub_zip_2 = pd.DataFrame([{'destination_zip' : '98032', 'record_id': 0 , 'unit_count' : 0}])
rs_zips = hub_zip_2.append(rs_zips).reset_index(drop=True)
nomi = pgeocode.Nominatim('us')
query = nomi.query_postal_code(rs_zips['destination_zip'].to_numpy())
rs_coords = []
for i in range (len(query)):
  rs_coords.insert(i, [query['longitude'][i], query['latitude'][i]])

# %%
# time requirements on the hub (after arrival at hub, give 2 hour waiting time, and 24 hour limit of item staying in the hub)
rs_time_windows = []
rs_time_windows.append([0,0])
rs_start_time = hub_arrivals['arrive_earliest'].min()
# maybe time windows must be in numbers instead of date and time
for i in range(len(hub_arrivals)):
#     rs_time_windows.append((hub_arrivals['arrive_earliest'][i] + timedelta(hours=2), hub_arrivals['arrive_earliest'][i] + timedelta(hours=26)))
    rs_time_windows.append((int((hub_arrivals['arrive_earliest'][i] -  rs_start_time +timedelta(hours = 2)).total_seconds()/60), int((hub_arrivals['arrive_earliest'][i] -  rs_start_time+ timedelta(hours = 26)).total_seconds()/60)))
print("start time is at")
print(rs_start_time)
rs_time_windows
# Out:
# start time is at
# 2020-09-22 03:06:04.820000
# [[0, 0],
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (120, 1560),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
#  (2340, 3780),
# ...

# %%
# build phase 2 time matrix
main_matrix = [[0]*len(rs_coords) for i in range(len(rs_coords))]
rem = len(rs_coords) % 50
# 
num_blocks = (int)((len(rs_coords) - rem) / 50)
if (num_blocks == 0):
  main_matrix = send_request(rs_coords + rs_coords, len(rs_coords))
else:

  for r in range(num_blocks):
    for c in range(num_blocks):
      dest = rs_coords[c * 50 : c * 50 + 50]
      orig = rs_coords[r * 50 : r * 50 + 50]
      dest = rs_coords[c * 50 : c * 50 + 50]

      small_matrix = send_request(orig + dest, len(orig))
      # join matrices to main matrix
      for i in range (len(small_matrix)):
        for j in range (len(small_matrix)):
          main_matrix[r*50 + i][c*50 + j] = small_matrix[i][j]
      # edge cases
    if (rem > 0):
      edge_orig = rs_coords[r*50 : r*50 +50]
      edge_dest = rs_coords[50*num_blocks : len(rs_coords)]
      edge_small_matrix = send_request(edge_orig + edge_dest, len(edge_orig))
    # join matrices to main matrix
      for i in range (len(edge_small_matrix)):
        for j in range (len(edge_small_matrix[0])):
          main_matrix[r*50 + i][num_blocks*50 + j] = edge_small_matrix[i][j]

  # bottom edge cases
  if (rem > 0):
      for j50 in range(num_blocks):
        orig = rs_coords[num_blocks*50 : len(rs_coords)]
        dest = rs_coords[j50*50 : j50*50 + 50]
        small_matrix = send_request(orig + dest, len(orig))
        # join matrices to main matrix
        for i in range (len(small_matrix)):
          for j in range (len(small_matrix[0])):
            main_matrix[num_blocks*50 + i][j50*50 + j] = small_matrix[i][j]
        # edge 
        orig = rs_coords[num_blocks*50 : len(rs_coords)]
        dest = rs_coords[50*num_blocks : len(rs_coords)]
        small_matrix = send_request(orig + dest, len(orig))
        # join matrices to main matrix
        for i in range (len(small_matrix)):
          for j in range (len(small_matrix[0])):
            main_matrix[num_blocks*50 + i][num_blocks*50 + j] = small_matrix[i][j]
        # print(main_matrix)

rs_time_matrix = np.array(main_matrix)/60
print(len(rs_time_matrix),"x",len(rs_time_matrix[0]),"time matrix constructed, second value = " + str(rs_time_matrix[0][1]))
# Out:
# 100 x 100 time matrix constructed, second value = 39.171166666666664

# %%
rs_zips
# Out:
#    destination_zip  record_id  unit_count
# 0            98032          0           0
# 1            98466          5        1075
# 2            98466          5        1075
# 3            98466          5        1075
# 4            98466          5        1075
# ..             ...        ...         ...
# 95           98116         25        1075
# 96           98122         25        1075
# 97           98466         25        1075
# 98           98052         25        1075
# 99           98004         25        1075
#
# [100 rows x 3 columns]

# %%
# hub to receiving sites solver
from functools import partial

from ortools.constraint_solver import pywrapcp
from ortools.constraint_solver import routing_enums_pb2

###########################
# Problem Data Definition #
###########################
def create_data_model():
    """Stores the data for the problem"""

    data = {}
    data['time_matrix'] = rs_time_matrix
    data['time_windows'] = rs_time_windows
    data['demands'] = rs_zips['unit_count']
    data['time_per_demand_unit'] = 0 # 0 minutes/unit
    data['temperature'] = temperature_filter
#     TODO: Change number of trucks
    data['num_16trucks'] = 5
    data['num_53trucks'] = 10
    data['num_vehicles'] = data['num_16trucks'] + data['num_53trucks']
    data['vehicle_capacities'] = [unit_capacity_16]*data['num_16trucks'] + [unit_capacity_53]*data['num_53trucks']
    data['depot'] = 0
    data['output'] = []
    return data


#######################
# Problem Constraints #
#######################

def create_demand_evaluator(data):
    """Creates callback to get demands at each location."""
    _demands = data['demands']

    def demand_evaluator(manager, node):
        """Returns the demand of the current node"""
        return _demands[manager.IndexToNode(node)]

    return demand_evaluator


def create_time_evaluator(data):
    def travel_time(data, from_node, to_node):
        """Gets the travel times between two locations."""
        if from_node == to_node:
            travel_time = 0
        else:
            travel_time = data['time_matrix'][from_node][to_node]
        return travel_time

    _total_time = data['time_matrix']
    def time_evaluator(manager, from_node, to_node):
        """Returns the total time between the two nodes"""
        return _total_time[manager.IndexToNode(from_node)][manager.IndexToNode(
            to_node)]
    return time_evaluator

# cost evaluator per vehicle
def create_cost_evaluator(data,vehindex):
    """Created call back to get total cost between locations """
    def travel_cost(data, from_node, to_node):
        if from_node == to_node:
            return 0
        else:
            hrs = (float)(data['time_matrix'][from_node][to_node] / 60)
            
            if (data['vehicle_capacities'][vehindex] == unit_capacity_16):
                rent = rent_16
                labor = labor_16
                mpg = mpg_16
                temp_cost = b_info['temp_cost_16']
            elif (data['vehicle_capacities'][vehindex] == unit_capacity_53):
                rent = rent_53
                labor = labor_53
                mpg = mpg_53
                temp_cost = b_info['temp_cost_53']
            cost = (rent + labor + temp_cost) * hrs + gas_price * hrs * truck_speed/mpg
            return cost
        
    _total_cost = [[0]*len(data['demands']) for i in range(len(data['demands']))]
    for from_node in range(len(data['demands'])):
        _total_cost[from_node] = {}
        for to_node in range(len(data['demands'])):
            if from_node == to_node:
                _total_cost[from_node][to_node] = 0
            else:
                _total_cost[from_node][to_node] = (travel_cost(data, from_node, to_node))
    def cost_evaluator(manager, from_node, to_node):
        return _total_cost[manager.IndexToNode(from_node)][manager.IndexToNode(
            to_node)]
    return cost_evaluator

def add_capacity_constraints(routing, data, demand_evaluator_index):
    """Adds capacity constraint"""
    capacity = 'Capacity'
    routing.AddDimensionWithVehicleCapacity(
        demand_evaluator_index,
        0,  # null capacity slack
        data['vehicle_capacities'],
        True,  # start cumul to zero
        capacity)

def add_time_window_constraints(routing, manager, data, time_evaluator_index):
    """Add Global Span constraint"""
    time = 'Time'
    horizon = 12000000
    routing.AddDimension(
        time_evaluator_index,
        horizon,  # allow waiting time
        horizon,  # maximum time per vehicle
        False,  # don't force start cumul to zero since we are giving TW to start nodes
        time)
    time_dimension = routing.GetDimensionOrDie(time)
    # Add time window constraints for each location except depot
    # and 'copy' the slack var in the solution object (aka Assignment) to print it
    for location_idx, time_window in enumerate(data['time_windows']):
        if location_idx == 0:
            continue
        index = manager.NodeToIndex(location_idx)
        time_dimension.CumulVar(index).SetRange(time_window[0], time_window[1])
        routing.AddToAssignment(time_dimension.SlackVar(index))
    # Add time window constraints for each vehicle start node
    # and 'copy' the slack var in the solution object (aka Assignment) to print it
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        time_dimension.CumulVar(index).SetRange(data['time_windows'][0][0],
                                                data['time_windows'][0][1])
        routing.AddToAssignment(time_dimension.SlackVar(index))
        # Warning: Slack var is not defined for vehicle's end node
        #routing.AddToAssignment(time_dimension.SlackVar(self.routing.End(vehicle_id)))


###########
# Printer #
###########

# change the arrive earliest to depotTime + the specified time in minutes.
def print_solution(data, manager, routing, assignment):  # pylint:disable=too-many-locals
    """Prints assignment on console"""
    print('Objective: {}'.format(assignment.ObjectiveValue()))
    total_distance = 0
    total_load = 0
    total_time = 0
    capacity_dimension = routing.GetDimensionOrDie('Capacity')
    time_dimension = routing.GetDimensionOrDie('Time')
    
    run_id = []
    record_id = []
    drop_off_zip = []
    arrive_earliest = []
    arrive_latest = []
    destination_zip = []
    depart_earliest = []
    depart_latest = []
    arrival_if_leave_now = []
    truck_id = []
    truck_type = []
    unit_count = []
    temperature = []
    cost = []
    
    c = create_time_evaluator(data)
    
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        distance = 0
        while not routing.IsEnd(index):
            load_var = capacity_dimension.CumulVar(index)
            time_var = time_dimension.CumulVar(index)
            slack_var = time_dimension.SlackVar(index)

            run_id.append(len(run_id) + 1)
            record_id.append(rs_zips['record_id'][manager.IndexToNode(index)])
            drop_off_zip.append(rs_zips['destination_zip'][manager.IndexToNode(index)])
            arrive_earliest.append(rs_start_time + timedelta(minutes = assignment.Min(time_var)))
            arrive_latest.append(rs_start_time + timedelta(minutes = assignment.Max(time_var)))
            destination_zip.append(rs_zips['destination_zip'][manager.IndexToNode(assignment.Value(routing.NextVar(index)))])
            depart_earliest.append(rs_start_time + timedelta(minutes = assignment.Min(time_var) + assignment.Min(slack_var)))
            depart_latest.append(rs_start_time + timedelta(minutes = assignment.Min(time_var) + assignment.Max(slack_var)))
            arrival_if_leave_now.append(depart_earliest[len(depart_earliest) - 1] + timedelta(minutes = data['time_matrix'][manager.IndexToNode(index)][manager.IndexToNode(assignment.Value(routing.NextVar(index)))]))
            truck_id.append(vehicle_id)
            if (vehicle_id + 1  <= data['num_16trucks']):
                truck_type.append("16'")
            else:
                truck_type.append("53'")
            unit_count.append(rs_zips['unit_count'][manager.IndexToNode(index)])
            temperature.append(temperature_filter)
            cost.append(routing.GetArcCostForVehicle(index, assignment.Value(routing.NextVar(index)), vehicle_id))
            plan_output +='{0} Load({1}) Time({2},{3}) Slack({4},{5}) Cost({6})-> {7}\n'.format(
            manager.IndexToNode(index),
            assignment.Value(load_var),
            assignment.Min(time_var),
            assignment.Max(time_var),
            assignment.Min(slack_var), assignment.Max(slack_var),
            routing.GetArcCostForVehicle(index, assignment.Value(routing.NextVar(index)),
                                                 vehicle_id),
            manager.IndexToNode(assignment.Value(routing.NextVar(index))))
            previous_index = index
            index = assignment.Value(routing.NextVar(index))
            distance += routing.GetArcCostForVehicle(previous_index, index,
                                                     vehicle_id)
        load_var = capacity_dimension.CumulVar(index)
        time_var = time_dimension.CumulVar(index)
        slack_var = time_dimension.SlackVar(index)
        plan_output += '{0} Load({1}) Time({2},{3})\n'.format(
            manager.IndexToNode(index),
            assignment.Value(load_var),
            assignment.Min(time_var), assignment.Max(time_var))
        plan_output += 'Cost of the route: {0}m\n'.format(distance)
        plan_output += 'Load of the route: {}\n'.format(
            assignment.Value(load_var))
        plan_output += 'Time of the route: {}\n'.format(
            assignment.Value(time_var))
        print(plan_output)
        total_distance += distance
        total_load += assignment.Value(load_var)
        total_time += assignment.Value(time_var)
    print('Total Cost of all routes: {0}m'.format(total_distance))
    print('Total Load of all routes: {}'.format(total_load))
    print('Total Time of all routes: {0}min'.format(total_time))
    d = {'run_id':run_id, 'record_id': record_id, 'arrive_earliest' : pd.to_datetime(arrive_earliest), 
         'arrive_latest' : pd.to_datetime(arrive_latest), 'drop_off_zip' : drop_off_zip, 'depart_earliest' : pd.to_datetime(depart_earliest),
         'depart_latest' : pd.to_datetime(depart_latest), 'arrival_if_leave_now': arrival_if_leave_now,  'destination_zip' : destination_zip, 'truck_id' : truck_id, 'truck_type' : truck_type, 'unit_count' : unit_count, 'temperature' : temperature,
         'cost' : cost}
    output = pd.DataFrame(data=d)
    return output

########
# Main #
########
"""Entry point of the program"""
# Instantiate the data problem.
data = create_data_model()

# Create the routing index manager
manager = pywrapcp.RoutingIndexManager(len(data['demands']),
                                       data['num_vehicles'], data['depot'])

# Create Routing Model
routing = pywrapcp.RoutingModel(manager)

# Define weight of each edge
for i in range(data['num_vehicles']):
    cost_evaluator_index = routing.RegisterTransitCallback(
        partial(create_cost_evaluator(data, i), manager))
    routing.SetArcCostEvaluatorOfVehicle(cost_evaluator_index, i)

# Add Capacity constraint
demand_evaluator_index = routing.RegisterUnaryTransitCallback(
    partial(create_demand_evaluator(data), manager))
add_capacity_constraints(routing, data, demand_evaluator_index)

# Add Time Window constraint
time_evaluator_index = routing.RegisterTransitCallback(
    partial(create_time_evaluator(data), manager))
add_time_window_constraints(routing, manager, data, time_evaluator_index)

# Setting first solution heuristic (cheapest addition).
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)  # pylint: disable=no-member
# Solve the problem.
assignment = routing.SolveWithParameters(search_parameters)
rs_output = print_solution(data, manager, routing, assignment)
# Out:
# Objective: 1728
# Route for vehicle 0:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 1:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 2:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 3:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 4:
# 0 Load(0) Time(0,0) Slack(0,12000000) Cost(0)-> 0
# 0 Load(0) Time(0,12000000)
# Cost of the route: 0m
# Load of the route: 0
# Time of the route: 0
#
# Route for vehicle 5:
# 0 Load(0) Time(0,0) Slack(71,1511) Cost(104)-> 26
# ...

# %%
# in this table, the "action" should be "drop off"
# e.g. line 7: drop off 8697 units of item#15 at rec. site 98052

rs_output
# Out:
#      run_id  record_id         arrive_earliest           arrive_latest  \
# 0         1          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 1         2          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 2         3          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 3         4          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 4         5          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# ..      ...        ...                     ...                     ...
# 109     110          3 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
# 110     111          3 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
# 111     112          9 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
# 112     113         10 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
# 113     114         10 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
#
#     drop_off_zip         depart_earliest           depart_latest  \
# ...

# %%
# combine similar trips
i = 0
rs_joined = rs_output.copy().sort_values(by="cost", ascending = False)
rs_joined = rs_joined.reset_index(drop=True)
while (i < len(rs_joined)):
    if (i < len(rs_joined)): 
        row = i
        same_id = rs_joined['record_id'] == rs_joined['record_id'][row]
        same_pickup = rs_joined['drop_off_zip'] == rs_joined['drop_off_zip'][row]
        same_dest = rs_joined['destination_zip'] == rs_joined['drop_off_zip']
        same_truck = rs_joined['truck_id'] == rs_joined['truck_id'][row]
        diff_run = rs_joined['run_id'] != rs_joined['run_id'][row]
        dup = rs_joined.loc[same_id & same_pickup & same_dest & same_truck & diff_run]
        if (len(dup) > 1):
#             delete rows
            rs_joined = rs_joined.loc[~(same_id & same_pickup & same_dest & same_truck & diff_run)]  
            rs_joined['unit_count'][row] += dup['unit_count'].sum() 
            i -=1
            rs_joined = rs_joined.reset_index(drop = True) 
    i+=1
rs_joined['run_id'] = range(len(rs_joined))
print(rs_output['unit_count'].sum() - rs_joined['unit_count'].sum())
print(rs_output['cost'].sum() - rs_joined['cost'].sum())
rs_joined
# Out:
# 0
# 0
#     run_id  record_id         arrive_earliest           arrive_latest  \
# 0        0          5 2020-09-22 05:06:04.820 2020-09-23 05:06:04.820
# 1        1         25 2020-09-26 10:08:04.820 2020-09-27 10:08:04.820
# 2        2          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 3        3          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 4        4         25 2020-09-26 10:08:04.820 2020-09-27 10:08:04.820
# 5        5         25 2020-09-26 10:08:04.820 2020-09-27 10:08:04.820
# 6        6         10 2020-09-26 10:08:04.820 2020-09-27 02:47:04.820
# 7        7         13 2020-09-26 02:47:04.820 2020-09-27 02:47:04.820
# 8        8          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 9        9          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 10      10          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# 11      11          0 2020-09-22 03:06:04.820 2020-09-22 03:06:04.820
# ...

# %%
# making sure the trucks are dropping things of at the right place
for i in range(len(receiving_sites)):
    print(rs_joined[rs_joined['drop_off_zip'] == receiving_sites[i]]['unit_count'].sum())
print(units_distribution)
# Out:
# 20425
# 20425
# 20105
# 18586
# 19749
# [20425, 20425, 20105, 18586, 19749]

# %%
# add truck id of previous output
p1_output_by_temp[temperature_filter] = joined
p2_output_by_temp[temperature_filter] = rs_joined
print(len(p1_output_by_temp[temperature_filter]))
print(len(p2_output_by_temp[temperature_filter]))
# Out:
# 53
# 41

# %%
# import sqlalchemy 
# from sqlalchemy import create_engine
# # engine = sqlalchemy.create_engine("mssql+pyodbc://54.174.212.175:CaVysyb@W2200am$@testingDatabase.db")

# cnxn = pyodbc.connect("DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;PORT=1433;DATABASE=testingdatabase;UID=sa;PWD=CaVysyb@W2200am$")
# cursor = cnxn.cursor()

# for index, row in output.iterrows():
#     cursor.execute("INSERT INTO HumanResources.DepartmentTest (DepartmentID,Name,GroupName) values(?,?,?)", row.DepartmentID, row.Name, row.GroupName)
# cnxn.commit()
# cursor.close()

# # write the DataFrame to a table in the sql database
# # output.to_sql("outputTest", engine)

# %%
# import pyodbc
# import sqlite3 as db
# import csv

# cnxn = pyodbc.connect("DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;PORT=1433;DATABASE=testingdatabase;UID=sa;PWD=CaVysyb@W2200am$")

# cur = cnxn.cursor()
# #From '/var/opt/mssql/export_dataframe.csv'
# sql = """ 
# Bulk Insert tblFinal_phase1_output
# From '/var/opt/mssql/final_p1_output.csv'
# With (
# Firstrow = 2,
# FIELDTERMINATOR = ',', 
# ROWTERMINATOR = '0x0A'
# ); 

# Select  run_id, record_id,arrive_earliest,
# pickup_zip,depart_earliest,depart_latest,arrival_if_leave_now,destination_zip,truck_id,truck_type,unit_count,temperature,cost,
# Count(*) AS toal_count
# From tblFinal_phase1_output 

# Group By 
# run_id, record_id,arrive_earliest
# pickup_zip,depart_earliest,depart_latest,arrival_if_leave_now,destination_zip,truck_id,truck_type,unit_count,temperature,cost

# """

# cur.execute(sql)
# cnxn.commit()
# cnxn.close()

# %%
# import pyodbc
# import sqlite3 as db
# import csv

# cnxn = pyodbc.connect("DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;PORT=1433;DATABASE=testingdatabase;UID=sa;PWD=CaVysyb@W2200am$")

# cur = cnxn.cursor()
# #From '/var/opt/mssql/export_dataframe.csv'
# sql = """ 
# Bulk Insert tblFinal_phase2_output
# From '/var/opt/mssql/final_p2_output.csv'
# With (
# Firstrow = 2,
# FIELDTERMINATOR = ',', 
# ROWTERMINATOR = '0x0A'
# ); 
# """

# cur.execute(sql)
# cnxn.commit()
# cnxn.close()
